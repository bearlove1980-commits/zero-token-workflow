# %% [markdown]
# <a href="https://colab.research.google.com/github/bearlove1980-commits/zero-token-workflow/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/bearlove1980-commits/zero-token-workflow.git
# %cd zero-token-workflow
# !pip install playwright -q
# !playwright install chromium
print("セットアップ完了！")
# Out:
# Cloning into 'zero-token-workflow'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 12.14 KiB | 12.14 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/zero-token-workflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 18.7 MB/s eta 0:00:00
# ...
# (node:6325) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# ...

# %%
from typing import clear_overloads
# セッション記憶を保存
# !python session_memory.py save
# Out:
# セッションサマリーを入力してください:
# > ColabでZero Token Workflowのセットアップ完了
# 学んだこと（空行で終了）:
# > iPadだけでGitHubとColabを使ってセットアップできた
# >
# 次のアクション（空行で終了）:
# > NotebookLMで実際に文書を分析してみる
# >
# セッションを保存しました: memory/sessions/20260411_134310.json

# %%
# モックモードで動作確認
# !python workflow.py analyze \
  --sources "https://www.nhk.or.jp" \
  --query "このサイトの内容を要約して" \
  --mock
# Out:
# 分析開始: 1件のソース
# クエリ: このサイトの内容を要約して
# クエリファイルを生成しました: output/query_20260411_134310.md
# モックモード: output/query_20260411_134310.md を編集して結果を貼り付けてください
